# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# show all columns 
pd.set_option('display.max_columns', None)

# %%
# open beer_df.csv
beer_df = pd.read_csv('data/beer_df.csv', low_memory=False)
beer_df.head()
# Out:
#             address categories         city country  \
# 0  2010 Williams St    Brewery  San Leandro      US
# 1  2010 Williams St    Brewery  San Leandro      US
# 2  2010 Williams St    Brewery  San Leandro      US
# 3  2010 Williams St    Brewery  San Leandro      US
# 4  2010 Williams St    Brewery  San Leandro      US
#
#                                key        lat        long  \
# 0  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 1  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 2  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 3  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 4  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
#
#              brewery_name      phones  postalCode province  \
# 0  21st Amendment Brewery  5105952111       94577       CA
# 1  21st Amendment Brewery  5105952111       94577       CA
# 2  21st Amendment Brewery  5105952111       94577       CA
# 3  21st Amendment Brewery  5105952111       94577       CA
# 4  21st Amendment Brewery  5105952111       94577       CA
#
#                     websites    index  brewery_id  review_time  \
# 0  http://21st-amendment.com  1494802         735   1026313935
# 1  http://21st-amendment.com  1495017         735   1298940583
# 2  http://21st-amendment.com  1495350         735   1228417395
# 3  http://21st-amendment.com  1495733         735   1264280146
# 4  http://21st-amendment.com  1501253         735   1270753134
#
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             4.5           4.0                5.0               jool
# 1             3.5           3.5                4.0          illidurit
# 2             4.0           4.0                4.0       magictrokini
# 3             4.0           4.0                3.5     HapWifeHapLife
# 4             4.0           3.5                4.5           pwoody11
#
#                        beer_style  review_palate  review_taste  \
# 0                    American IPA            4.5           4.5
# 1  American Double / Imperial IPA            3.5           3.5
# 2                    American IPA            3.0           4.0
# 3                    American IPA            4.0           4.0
# 4         Belgian Strong Dark Ale            4.0           4.0
#
#             beer_name  beer_abv  beer_beerid
# 0            Hop Caen       7.0         4205
# 1             21 Rock       9.7        66190
# 2        Harvest Moon       6.4        45648
# 3  21st Amendment IPA       7.0        20781
# 4        Monk's Blood       8.3        52510

# %%
beer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167421 entries, 0 to 167420
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   address             167421 non-null  object
#  1   categories          167421 non-null  object
#  2   city                167421 non-null  object
#  3   country             167421 non-null  object
#  4   key                 167421 non-null  object
#  5   lat                 167421 non-null  float64
#  6   long                167421 non-null  float64
#  7   brewery_name        167421 non-null  object
#  8   phones              167421 non-null  object
#  9   postalCode          167421 non-null  int64
#  10  province            167421 non-null  object
#  11  websites            167421 non-null  object
#  12  index               167421 non-null  int64
#  13  brewery_id          167421 non-null  int64
#  14  review_time         167421 non-null  int64
#  15  review_overall      167421 non-null  float64
#  16  review_aroma        167421 non-null  float64
#  17  review_appearance   167421 non-null  float64
#  18  review_profilename  167421 non-null  object
#  19  beer_style          167421 non-null  object
#  20  review_palate       167421 non-null  float64
#  21  review_taste        167421 non-null  float64
#  22  beer_name           167421 non-null  object
#  23  beer_abv            167421 non-null  float64
#  24  beer_beerid         167421 non-null  int64
# dtypes: float64(8), int64(5), object(12)
# memory usage: 31.9+ MB

# %%
# convert review time to datetime
beer_df['review_time'] = pd.to_datetime(beer_df['review_time'], unit='s')

# %%
# create new column of year based on review time
beer_df['review_year'] = beer_df['review_time'].dt.year
beer_df.head()
# Out:
#             address categories         city country  \
# 0  2010 Williams St    Brewery  San Leandro      US
# 1  2010 Williams St    Brewery  San Leandro      US
# 2  2010 Williams St    Brewery  San Leandro      US
# 3  2010 Williams St    Brewery  San Leandro      US
# 4  2010 Williams St    Brewery  San Leandro      US
#
#                                key        lat        long  \
# 0  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 1  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 2  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 3  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 4  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
#
#              brewery_name      phones  postalCode province  \
# 0  21st Amendment Brewery  5105952111       94577       CA
# 1  21st Amendment Brewery  5105952111       94577       CA
# 2  21st Amendment Brewery  5105952111       94577       CA
# 3  21st Amendment Brewery  5105952111       94577       CA
# 4  21st Amendment Brewery  5105952111       94577       CA
#
#                     websites    index  brewery_id         review_time  \
# 0  http://21st-amendment.com  1494802         735 2002-07-10 15:12:15
# 1  http://21st-amendment.com  1495017         735 2011-03-01 00:49:43
# 2  http://21st-amendment.com  1495350         735 2008-12-04 19:03:15
# 3  http://21st-amendment.com  1495733         735 2010-01-23 20:55:46
# 4  http://21st-amendment.com  1501253         735 2010-04-08 18:58:54
#
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             4.5           4.0                5.0               jool
# 1             3.5           3.5                4.0          illidurit
# 2             4.0           4.0                4.0       magictrokini
# 3             4.0           4.0                3.5     HapWifeHapLife
# 4             4.0           3.5                4.5           pwoody11
#
#                        beer_style  review_palate  review_taste  \
# 0                    American IPA            4.5           4.5
# 1  American Double / Imperial IPA            3.5           3.5
# 2                    American IPA            3.0           4.0
# 3                    American IPA            4.0           4.0
# 4         Belgian Strong Dark Ale            4.0           4.0
#
#             beer_name  beer_abv  beer_beerid  review_year
# 0            Hop Caen       7.0         4205         2002
# 1             21 Rock       9.7        66190         2011
# 2        Harvest Moon       6.4        45648         2008
# 3  21st Amendment IPA       7.0        20781         2010
# 4        Monk's Blood       8.3        52510         2010

# %%
# create new column of month based on review time
beer_df['review_month'] = beer_df['review_time'].dt.month
beer_df.head()
# Out:
#             address categories         city country  \
# 0  2010 Williams St    Brewery  San Leandro      US
# 1  2010 Williams St    Brewery  San Leandro      US
# 2  2010 Williams St    Brewery  San Leandro      US
# 3  2010 Williams St    Brewery  San Leandro      US
# 4  2010 Williams St    Brewery  San Leandro      US
#
#                                key        lat        long  \
# 0  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 1  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 2  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 3  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 4  us/ca/sanleandro/2010williamsst  37.711807 -122.177658
#
#              brewery_name      phones  postalCode province  \
# 0  21st Amendment Brewery  5105952111       94577       CA
# 1  21st Amendment Brewery  5105952111       94577       CA
# 2  21st Amendment Brewery  5105952111       94577       CA
# 3  21st Amendment Brewery  5105952111       94577       CA
# 4  21st Amendment Brewery  5105952111       94577       CA
#
#                     websites    index  brewery_id         review_time  \
# 0  http://21st-amendment.com  1494802         735 2002-07-10 15:12:15
# 1  http://21st-amendment.com  1495017         735 2011-03-01 00:49:43
# 2  http://21st-amendment.com  1495350         735 2008-12-04 19:03:15
# 3  http://21st-amendment.com  1495733         735 2010-01-23 20:55:46
# 4  http://21st-amendment.com  1501253         735 2010-04-08 18:58:54
#
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             4.5           4.0                5.0               jool
# 1             3.5           3.5                4.0          illidurit
# 2             4.0           4.0                4.0       magictrokini
# 3             4.0           4.0                3.5     HapWifeHapLife
# 4             4.0           3.5                4.5           pwoody11
#
#                        beer_style  review_palate  review_taste  \
# 0                    American IPA            4.5           4.5
# 1  American Double / Imperial IPA            3.5           3.5
# 2                    American IPA            3.0           4.0
# 3                    American IPA            4.0           4.0
# 4         Belgian Strong Dark Ale            4.0           4.0
#
#             beer_name  beer_abv  beer_beerid  review_year  review_month
# 0            Hop Caen       7.0         4205         2002             7
# 1             21 Rock       9.7        66190         2011             3
# 2        Harvest Moon       6.4        45648         2008            12
# 3  21st Amendment IPA       7.0        20781         2010             1
# 4        Monk's Blood       8.3        52510         2010             4

# %% [markdown]
# ## Data Visualization

# %%
# plot review count by year
beer_df.groupby('review_year')['review_overall'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='review_year'>

# %%
# plot review count by month
beer_df.groupby('review_month')['review_overall'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='review_month'>

# %%
# plot review count by brewery
beer_df.groupby('brewery_name')['review_overall'].count().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='brewery_name'>

# %% [markdown]
# ## Data Modeling

# %%
# create baseline model of beer_df with normal_predictor and train test split from surprise using this link: 
#https://www.alldatascience.com/recommender-systems/simple-recipe-recommender-system-with-scikit-surprise/
from surprise import NormalPredictor
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)

trainset, testset = train_test_split(data, test_size=.25)

algo = NormalPredictor()
algo.fit(trainset)
predictions = algo.test(testset)

accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 0.8725
# MAE:  0.6860
# 0.6859665813483948

# %% [markdown]
# Our Baseline Model has shown a decent overall start, with our rmse and mae being high. Next we will try to improve those metrics.

# %%
# create a model of beer_df with knn_basic and train test split from surprise using this link: https://www.alldatascience.com/recommender-systems/simple-recipe-recommender-system-with-scikit-surprise/
from surprise import KNNBasic
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)

trainset, testset = train_test_split(data, test_size=.25)

algo = KNNBasic()
algo.fit(trainset)
predictions = algo.test(testset)

accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.5767
# MAE:  0.4276
# 0.4275791542638054

# %% [markdown]
# Our KNNBasic model has improved the metrics as the rmse and mae are better and lower than the NormalPredictor model. Lets try to improve this with KNNwithMeans.

# %%
# create a model of beer_df with knn_with_means and train test split from surprise using this link: https://www.alldatascience.com/recommender-systems/simple-recipe-recommender-system-with-scikit-surprise/
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)

trainset, testset = train_test_split(data, test_size=.25)

algo = KNNWithMeans()
algo.fit(trainset)
predictions = algo.test(testset)

accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.5910
# MAE:  0.4390
# 0.43903969168902707

# %% [markdown]
# Our model has roughly worse measures between both the KNN models. Next we will try the famous SVD algoritm before tuning our parameters.

# %%
# Running a model with SVD
from surprise import SVD
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)

trainset, testset = train_test_split(data, test_size=.25)

algo = SVD()
algo.fit(trainset)
predictions = algo.test(testset)

accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 0.5580
# MAE:  0.4165
# 0.416463579882379

# %% [markdown]
# Our SVD Model has the best overall rmse and mae compared to our other models. We can now try it with more factors to see if any changes will occur.

# %%
# run another model with SVD with recommended amomunt of parameters but with a model size of 50 
from surprise import SVD
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1.0, 5.0))
data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)

trainset, testset = train_test_split(data, test_size=.25)

algo = SVD(n_factors=50)
algo.fit(trainset)

predictions = algo.test(testset)

accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 0.5623
# MAE:  0.4189
# 0.4188983605936585

# %% [markdown]
# Our original SVD Model has the best overall rmse and mae compared to our other models. Now we can try tuning our parameters to improve our accuracy.

# %% [markdown]
# Following collaborative recommendation system was influenced by mxie87 on github.
#
# Creating new dataframe of only data needed in model.
# Use both surprise library an sklearn.

# %%
# use this link to create collaborative recommendation system:https://github.com/mxie87/Beer_Recommender_CF/blob/master/BEER_RECOMMENDER_CF.ipynb

# %%
# create new dataframe of beer_df with only the columns needed for the model
reviews_df = beer_df[['beer_name', 'review_profilename', 'review_overall']]
reviews_df.head()
# Out:
#             beer_name review_profilename  review_overall
# 0            Hop Caen               jool             4.5
# 1             21 Rock          illidurit             3.5
# 2        Harvest Moon       magictrokini             4.0
# 3  21st Amendment IPA     HapWifeHapLife             4.0
# 4        Monk's Blood           pwoody11             4.0

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167421 entries, 0 to 167420
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   beer_name           167421 non-null  object
#  1   review_profilename  167421 non-null  object
#  2   review_overall      167421 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 3.8+ MB

# %%
grouped_beers = reviews_df.groupby('beer_name')
grouped_beers.count().sort_values(by='review_profilename', ascending = False).quantile(np.arange(0,1,.05))
# Out:
#       review_profilename  review_overall
# 0.00                 1.0             1.0
# 0.05                 1.0             1.0
# 0.10                 1.0             1.0
# 0.15                 2.0             2.0
# 0.20                 2.0             2.0
# 0.25                 3.0             3.0
# 0.30                 3.0             3.0
# 0.35                 4.0             4.0
# 0.40                 5.0             5.0
# 0.45                 6.0             6.0
# 0.50                 8.0             8.0
# 0.55                10.0            10.0
# 0.60                14.0            14.0
# 0.65                19.0            19.0
# 0.70                26.3            26.3
# 0.75                41.0            41.0
# 0.80                67.0            67.0
# 0.85               106.0           106.0
# 0.90               192.1           192.1
# 0.95               408.0           408.0

# %% [markdown]
# About 90% of beers have almost 200 ratings

# %%
grouped_beers.mean().sort_values(by='review_overall', ascending = False).quantile(np.arange(0,1,.05))
# Out:
#       review_overall
# 0.00        1.000000
# 0.05        3.000000
# 0.10        3.363287
# 0.15        3.500000
# 0.20        3.562500
# 0.25        3.660535
# 0.30        3.750000
# 0.35        3.789642
# 0.40        3.833333
# 0.45        3.892881
# 0.50        3.940207
# 0.55        4.000000
# 0.60        4.000000
# 0.65        4.000000
# 0.70        4.068730
# 0.75        4.125000
# 0.80        4.182597
# 0.85        4.250000
# 0.90        4.375000
# 0.95        4.500000

# %%
avg_rating = grouped_beers.mean()

# I am definining beers with average rating less than 3.5 to be considered subpar 
# since a 3.5 avg rating would put it in the bottom 10 percentile of these beers
subpar_average_mask = avg_rating['review_overall'] < 3.5
subpar_beers_count = len(avg_rating[subpar_average_mask])

print('There are {} unique beers in the dataset'.format(len(reviews_df['beer_name'].unique())))
print('{} beers have a average rating less than 3.5'.format(subpar_beers_count))
print('A 3.5 avg rating puts the beer within the bottom 15%')
# Out:
# There are 2030 unique beers in the dataset
# 254 beers have a average rating less than 3.5
# A 3.5 avg rating puts the beer within the bottom 15%

# %%
grouped_users = reviews_df.groupby('review_profilename')

# %%
grouped_users_count = grouped_users.count()

counts = [1,2,3,4,5,10,15,20]
for ct in counts:
    num_users = grouped_users_count[grouped_users_count['review_overall'] <= ct].count()[0]
    print('{} users rated {} or less beers'.format(num_users,ct))

print('\n')
print('Total Unique Users in this dataset: {}'.format(len(reviews_df.review_profilename.unique())))
# Out:
# 5205 users rated 1 or less beers
# 7128 users rated 2 or less beers
# 8262 users rated 3 or less beers
# 8976 users rated 4 or less beers
# 9538 users rated 5 or less beers
# 11041 users rated 10 or less beers
# 11866 users rated 15 or less beers
# 12367 users rated 20 or less beers
#
#
# Total Unique Users in this dataset: 14440

# %% [markdown]
# Majority of users have rated less than a few beers, with more than half rating less than 5 beers.

# %% [markdown]
# In order to improve results of recommendation system.
#
# I have considered dropping the last 15% of the data in terms of average rating and user activity. But with consideration to the surprise libraries "shrinkage factor", it will punish the items/users with little to no reviews.

# %%
# create a baseline model of entire dataset using collaborative filtering recommender system and train test split and surprise library
# https://towardsdatascience.com/building-and-testing-recommender-saystems-with-surprise-step-by-step-d4ba702ef80b

#import surprise
#from surprise import Reader, Dataset, SVD
#from surprise.accuracy import rmse, mae
#from surprise.model_selection import train_test_split
#
## create a reader object
#reader = Reader(rating_scale=(1, 5))
#
## create a dataset object
#data = Dataset.load_from_df(beer_df[['review_profilename', 'beer_name', 'review_overall']], reader)
#
## split data into train and test sets
#trainset, testset = train_test_split(data, test_size=0.25)
#
## create a SVD object
#svd = SVD()
#
## train the model
#svd.fit(trainset)
#
# predict ratings for the test set
#predictions = svd.test(testset)
#
## evaluate the model
#rmse(predictions)
#mae(predictions)

# create a function to predict the rating of a beer for a user
def predict_rating(user, beer):
    beer_id = beer_df[beer_df['beer_name'] == beer]['beer_beerid'].unique()[0]
    user_id = beer_df[beer_df['review_profilename'] == user]['review_profilename'].unique()[0]
    return svd.predict(user_id, beer_id).est

# create a function to recommend beers to a user
def recommend_beers(user, n):
    # get all beers reviewed by user
    reviewed_beers = beer_df[beer_df['review_profilename'] == user]['beer_name']
    # get all beers not reviewed by user
    not_reviewed = beer_df[beer_df['beer_name'].isin(reviewed_beers) == False]['beer_name'].unique()
    # create a dataframe of beers not reviewed by user
    not_reviewed_df = pd.DataFrame(not_reviewed, columns=['beer_name'])
    # add a predicted rating column to the dataframe
    not_reviewed_df['predicted_rating'] = not_reviewed_df['beer_name'].apply(lambda x: predict_rating(user, x))
    # sort the dataframe by predicted rating
    not_reviewed_df = not_reviewed_df.sort_values('predicted_rating', ascending=False)
    # return the top n beers
    return not_reviewed_df.head(n)

# recommend 10 beers to user 'Sean'
#recommend_beers('HapWifeHapLife', 10)

# create a function to recommend beers to a user based on a specific style
def recommend_beers_style(user, style, n):
    # get all beers reviewed by user
    reviewed_beers = beer_df[beer_df['review_profilename'] == user]['beer_name']
    # get all beers not reviewed by user
    not_reviewed = beer_df[~beer_df['beer_name'].isin(reviewed_beers)]['beer_name'].unique()
    # create a dataframe of beers not reviewed by user
    not_reviewed_df = pd.DataFrame(not_reviewed, columns=['beer_name'])
    # add a predicted rating column to the dataframe
    not_reviewed_df['predicted_rating'] = not_reviewed_df['beer_name'].apply(lambda x: predict_rating(user, x))
    # sort the dataframe by predicted rating
    not_reviewed_df = not_reviewed_df.sort_values('predicted_rating', ascending=False)
    # get all beers of a specific style
    style_df = beer_df[beer_df['beer_style'] == style]
    # remove any duplicate beer names from the style dataframe
    style_df = style_df.drop_duplicates(subset='beer_name')
    # merge the style dataframe with the not reviewed dataframe
    merged_df = pd.merge(not_reviewed_df, style_df, on='beer_name')
    # return the top n beers
    return merged_df.head(n)

# recommend 10 beers to user of style 'American IPA'
#recommend_beers_style('HapWifeHapLife', 'American IPA', 10)

# create a function to recommend beers to a user based on a specific brewery
def recommend_beers_brewery(user, brewery, n):
    # get all beers reviewed by user
    reviewed_beers = beer_df[beer_df['review_profilename'] == user]['beer_name']
    # get all beers not reviewed by user
    not_reviewed = beer_df[beer_df['beer_name'].isin(reviewed_beers) == False]['beer_name'].unique()
    # create a dataframe of beers not reviewed by user
    not_reviewed_df = pd.DataFrame(not_reviewed, columns=['beer_name'])
    # add a predicted rating column to the dataframe
    not_reviewed_df['predicted_rating'] = not_reviewed_df['beer_name'].apply(lambda x: predict_rating(user, x))
    # sort the dataframe by predicted rating
    not_reviewed_df = not_reviewed_df.sort_values('predicted_rating', ascending=False)
    # get all beers of a specific brewery
    brewery_df = beer_df[beer_df['brewery_name'] == brewery]
    # remove any duplicate beer names from the brewery dataframe
    brewery_df = brewery_df.drop_duplicates(subset='beer_name')
    # merge the brewery dataframe with the not reviewed dataframe
    merged_df = pd.merge(not_reviewed_df, brewery_df, on='beer_name')
    # return the top n beers
    return merged_df.head(n)

# recommend 10 beers to user of style specific brewery
#recommend_beers_brewery('HapWifeHapLife', 'Sierra Nevada Brewing Co.', 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-461c0eb5fb86> in <module>
#       3
#       4 # import libraries
# ----> 5 import surprise
#       6 from surprise import Reader, Dataset, SVD
#       7 from surprise.accuracy import rmse, mae
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/surprise/__init__.py in <module>
#      21 from .trainset import Trainset
#      22 from .builtin_datasets import get_dataset_dir
# ---> 23 from . import model_selection
#      24 from . import dump
#      25
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/surprise/model_selection/__init__.py in <module>
#       6 from .split import PredefinedKFold
#       7
# ----> 8 from .validation import cross_validate
#       9
#      10 from .search import GridSearchCV, RandomizedSearchCV
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/surprise/model_selection/validation.py in <module>
#       9
#      10 import numpy as np
# ---> 11 from joblib import Parallel
#      12 from joblib import delayed
#      13 from six import iteritems
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/__init__.py in <module>
#     118 from .numpy_pickle import load
#     119 from .compressor import register_compressor
# --> 120 from .parallel import Parallel
#     121 from .parallel import delayed
#     122 from .parallel import cpu_count
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in <module>
#      24 from .logger import Logger, short_format_time
#      25 from .disk import memstr_to_bytes
# ---> 26 from ._parallel_backends import (FallbackToBackend, MultiprocessingBackend,
#      27                                  ThreadingBackend, SequentialBackend,
#      28                                  LokyBackend)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in <module>
#      15
#      16 if mp is not None:
# ---> 17     from .pool import MemmappingPool
#      18     from multiprocessing.pool import ThreadPool
#      19     from .executor import get_memmapping_executor
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/pool.py in <module>
#      29 from io import BytesIO
#      30
# ---> 31 from ._memmapping_reducer import get_memmapping_reducers
#      32 from ._memmapping_reducer import TemporaryResourcesManager
#      33 from ._multiprocessing_helpers import mp, assert_spawning
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py in <module>
#       6 # License: BSD 3 clause
#       7
# ----> 8 from mmap import mmap
#       9 import errno
#      10 import os
#
# KeyboardInterrupt:

# %%
# recommend 10 beers to user
recommend_beers('HapWifeHapLife', 10)
# Out:
#                                   beer_name  predicted_rating
# 0                                  Hop Caen          3.976997
# 1348  Portsmouth Weenie Rocket With Siracha          3.976997
# 1361        Portsmouth Extra Special Bitter          3.976997
# 1360                  Portsmouth Killer Bee          3.976997
# 1359           Portsmouth Coffee Milk Stout          3.976997
# 1358              Portsmouth Pils Von Faust          3.976997
# 1357           Portsmouth Old Brown Dog Ale          3.976997
# 1356            Portsmouth Saison D'Automne          3.976997
# 1355                 Portsmouth Dunkel Gose          3.976997
# 1354                 Portsmouth Octoberfest          3.976997

# %%
# recommend 10 beers to user of style 'American IPA'
recommend_beers_style('HapWifeHapLife', 'American IPA', 10)
# Out:
#                       beer_name  predicted_rating                address  \
# 0                      Hop Caen          3.976997       2010 Williams St
# 1     Portsmouth Hop Harvest #1          3.976997           56 Market St
# 2          Portsmouth 5 C's IPA          3.976997           56 Market St
# 3  Portsmouth Bottle Rocket IPA          3.976997           56 Market St
# 4  Portsmouth Wild Duck Rye IPA          3.976997           56 Market St
# 5   Portsmouth Ginga' Ninja IPA          3.976997           56 Market St
# 6          Anniversary Ale 2011          3.976997  1430 Washington Ave S
# 7          Anniversary Ale 2010          3.976997  1430 Washington Ave S
# 8     Portsmouth Hop Harvest #2          3.976997           56 Market St
# 9    Saint Arnold Sailing Santa          3.976997         2000 Lyons Ave
#
#                                           categories         city country  \
# 0                                            Brewery  San Leandro      US
# 1                                       Brewery, Bar   Portsmouth      US
# 2                                       Brewery, Bar   Portsmouth      US
# 3                                       Brewery, Bar   Portsmouth      US
# 4                                       Brewery, Bar   Portsmouth      US
# 5                                       Brewery, Bar   Portsmouth      US
# 6  American Restaurant, Brewery and American Rest...  Minneapolis      US
# 7  American Restaurant, Brewery and American Rest...  Minneapolis      US
# 8                                       Brewery, Bar   Portsmouth      US
# 9                               Brewery, Beer Garden      Houston      US
#
#                                     key        lat        long  \
# 0       us/ca/sanleandro/2010williamsst  37.711807 -122.177658
# 1           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 2           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 3           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 4           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 5           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 6  us/mn/minneapolis/1430washingtonaves  44.973266  -93.247733
# 7  us/mn/minneapolis/1430washingtonaves  44.973266  -93.247733
# 8           us/nh/portsmouth/56marketst  43.078007  -70.757599
# 9            us/tx/houston/2000lyonsave  29.771590  -95.348790
#
#                     brewery_name      phones  postalCode province  \
# 0         21st Amendment Brewery  5105952111       94577       CA
# 1             Portsmouth Brewery  6034311115        3801       NH
# 2             Portsmouth Brewery  6034311115        3801       NH
# 3             Portsmouth Brewery  6034311115        3801       NH
# 4             Portsmouth Brewery  6034311115        3801       NH
# 5             Portsmouth Brewery  6034311115        3801       NH
# 6  Minneapolis Town Hall Brewery  6123398696       55454       MN
# 7  Minneapolis Town Hall Brewery  6123398696       55454       MN
# 8             Portsmouth Brewery  6034311115        3801       NH
# 9   Saint Arnold Brewing Company  7136869494       77020       TX
#
#                        websites    index  brewery_id         review_time  \
# 0     http://21st-amendment.com  1494802         735 2002-07-10 15:12:15
# 1  http://portsmouthbrewery.com  1434626         596 2011-09-28 05:11:12
# 2  http://portsmouthbrewery.com  1435877         596 2011-01-23 20:02:04
# 3  http://portsmouthbrewery.com  1435195         596 2010-10-16 02:03:23
# 4  http://portsmouthbrewery.com  1435600         596 2011-05-30 16:14:22
# 5  http://portsmouthbrewery.com  1435532         596 2011-12-28 20:53:43
# 6    http://townhallbrewery.com   357644        1177 2011-12-18 22:41:09
# 7    http://townhallbrewery.com   357464        1177 2011-12-01 00:49:25
# 8  http://portsmouthbrewery.com  1434235         596 2011-10-29 13:47:01
# 9    http://www.saintarnold.com  1092590         337 2012-01-09 13:19:24
#
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             4.5           4.0                5.0               jool
# 1             4.0           4.0                4.0          Bendurgin
# 2             4.5           4.0                5.0              dciBA
# 3             4.0           4.0                4.5           mdaschaf
# 4             4.5           4.5                3.5          Bendurgin
# 5             2.0           3.0                2.5           ffejherb
# 6             4.0           4.5                4.5            mothman
# 7             4.0           3.5                4.0            mothman
# 8             4.0           4.0                3.5             KTCamm
# 9             3.0           3.0                3.5          2378GCGTG
#
#      beer_style  review_palate  review_taste  beer_abv  beer_beerid  \
# 0  American IPA            4.5           4.5       7.0         4205
# 1  American IPA            3.0           4.0       6.5        20146
# 2  American IPA            4.0           4.5       6.5        44727
# 3  American IPA            4.0           4.0       6.5         5219
# 4  American IPA            4.0           4.0       6.3        69561
# 5  American IPA            2.5           2.5       6.5        70849
# 6  American IPA            4.0           4.0       6.8        74581
# 7  American IPA            4.0           4.0       6.5        62952
# 8  American IPA            3.5           4.0       6.0        45136
# 9  American IPA            3.5           3.0       7.0        75548
#
#    review_year  review_month
# 0         2002             7
# 1         2011             9
# 2         2011             1
# 3         2010            10
# 4         2011             5
# 5         2011            12
# 6         2011            12
# 7         2011            12
# 8         2011            10
# 9         2012             1

# %%
# recommend 10 beers to user of style specific brewery
recommend_beers_brewery('HapWifeHapLife', 'Sierra Nevada Brewing Co.', 10)
# Out:
#                                            beer_name  predicted_rating  \
# 0                                  Que Syrah, Syrah!          3.976997
# 1      Best Of Beer Camp: Double IPA - Beer Camp #29          3.976997
# 2                     Sierra Nevada Summerfest Lager          3.976997
# 3                  Loch Hop & Barrel - Beer Camp #35          3.976997
# 4                         Sierra Nevada Brown Saison          3.976997
# 5  Best Bitter Ale With Cascade And Chinook Dry Hops          3.976997
# 6  Empire Strikes Black Imperial Stout - Beer Cam...          3.976997
# 7                     Sticke Pilsner - Beer Camp #43          3.976997
# 8                    Snowed In Stout - Beer Camp #45          3.976997
# 9                                       Pitch-A-Tent          3.976997
#
#           address                                         categories   city  \
# 0  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 1  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 2  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 3  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 4  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 5  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 6  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 7  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 8  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
# 9  1075 E 20th St  Brew Pubs, Restaurants, Pub, Brewery, Liquor S...  Chico
#
#   country                      key        lat        long  \
# 0      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 1      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 2      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 3      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 4      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 5      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 6      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 7      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 8      US  us/ca/chico/1075e20thst  39.724604 -121.815715
# 9      US  us/ca/chico/1075e20thst  39.724604 -121.815715
#
#                 brewery_name                  phones  postalCode province  \
# 0  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 1  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 2  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 3  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 4  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 5  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 6  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 7  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 8  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
# 9  Sierra Nevada Brewing Co.  5308933520, 5303452739       95928       CA
#
#                       websites  index  brewery_id         review_time  \
# 0  http://www.sierranevada.com  70903         140 2010-03-04 13:32:28
# 1  http://www.sierranevada.com  76120         140 2011-12-06 20:57:20
# 2  http://www.sierranevada.com  76053         140 2005-06-07 23:17:26
# 3  http://www.sierranevada.com  73947         140 2011-02-18 18:11:11
# 4  http://www.sierranevada.com  73860         140 2011-01-03 21:07:41
# 5  http://www.sierranevada.com  73508         140 2009-09-20 04:48:15
# 6  http://www.sierranevada.com  73319         140 2011-05-22 14:42:31
# 7  http://www.sierranevada.com  72492         140 2011-04-30 06:51:57
# 8  http://www.sierranevada.com  72490         140 2011-12-06 21:06:16
# 9  http://www.sierranevada.com  72488         140 2011-12-12 10:07:44
#
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             4.5           4.0                4.0             WesWes
# 1             4.0           4.0                4.0         CampusCrew
# 2             3.5           3.0                3.0            ybnorml
# 3             2.0           3.0                3.5         drummstikk
# 4             4.5           3.5                4.0            Swimsum
# 5             5.0           3.0                4.0       ThreeWiseMen
# 6             4.0           4.0                4.0    barleywinefiend
# 7             4.0           4.0                4.0      womencantsail
# 8             4.0           4.0                4.0         CampusCrew
# 9             4.0           4.5                4.0        tylerprince
#
#                          beer_style  review_palate  review_taste  beer_abv  \
# 0            Saison / Farmhouse Ale            4.0           4.0      8.41
# 1    American Double / Imperial IPA            4.0           4.5      8.50
# 2                    Czech Pilsener            3.5           3.0      5.00
# 3            Scotch Ale / Wee Heavy            4.0           2.0      8.00
# 4            Saison / Farmhouse Ale            4.0           4.5      7.85
# 5                    English Bitter            4.5           4.5      4.60
# 6            Russian Imperial Stout            4.0           4.0      9.80
# 7                   German Pilsener            3.5           3.5      6.00
# 8  American Double / Imperial Stout            4.0           4.0      9.20
# 9           Belgian Strong Pale Ale            4.0           3.5      9.00
#
#    beer_beerid  review_year  review_month
# 0        56565         2010             3
# 1        68958         2011            12
# 2         3558         2005             6
# 3        66346         2011             2
# 4        49351         2011             1
# 5        52755         2009             9
# 6        50413         2011             5
# 7        66425         2011             4
# 8        75798         2011            12
# 9        74167         2011            12
